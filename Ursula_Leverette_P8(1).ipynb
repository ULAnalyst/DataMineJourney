# %% [markdown]
# # Project 8 -- Ursula Leverette

# %% [markdown]
# **TA Help:**
#
#
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Overflow
#
# (describe any information that you learned from internet resources, including the URLs)
#
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).
#
# ## Question 1
#
#  - 1.1. Lahman database copied to your local folder in anvil
#  - 1.2. Query that returns the first 5 rows of the "Teams" table from Lahman database.

# %%
import sqlite3 # import the sqlite library to connect and work with databases in Python

# %%
read_only_Lahman = sqlite3.connect('/anvil/projects/tdm/data/lahman/lahman.db') # load the lahman database from read-only location
local_lahman = sqlite3.connect('./lahman.db') # create a local copy of the lahman database on my system. 

read_only_Lahman.backup(local_lahman) # use the backup feature to compy all data from the read-only database to my local file. 
read_only_Lahman.close() # close both database connections to complete the operation. 
local_lahman.close()

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From Teams
# Limit 5;
# Out:
# Done.
# [(1871, 'NA', 'BS1', 'BNA', '', 3, 31, '', 20, 10, '', '', 'N', '', 401, 1372, 426, 70, 37, 3, 60, 19, 73, 16, '', '', 303, 109, 3.55, 22, 1, 3, 828, 367, 2, 42, 23, 243, 24, 0.834, 'Boston Red Stockings', 'South End Grounds I', '', 103, 98, 'BOS', 'BS1', 'BS1'),
#  (1871, 'NA', 'CH1', 'CNA', '', 2, 28, '', 19, 9, '', '', 'N', '', 302, 1196, 323, 52, 21, 10, 60, 22, 69, 21, '', '', 241, 77, 2.76, 25, 0, 1, 753, 308, 6, 28, 22, 229, 16, 0.829, 'Chicago White Stockings', 'Union Base-Ball Grounds', '', 104, 102, 'CHI', 'CH1', 'CH1'),
#  (1871, 'NA', 'CL1', 'CFC', '', 8, 29, '', 10, 19, '', '', 'N', '', 249, 1186, 328, 35, 40, 7, 26, 25, 18, 8, '', '', 341, 116, 4.11, 23, 0, 0, 762, 346, 13, 53, 34, 234, 15, 0.818, 'Cleveland Forest Citys', 'National Association Grounds', '', 96, 100, 'CLE', 'CL1', 'CL1'),
# ...

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # connect to the local copy of the Lahman database
# Select *
# # select all columns
# From Teams
# # choose the Teams table
# Limit 5;
# # limit output to the first 5 rows

# %%
read_only_chinook = sqlite3.connect('/anvil/projects/tdm/data/chinook/Chinook_Sqlite.sqlite') # load the chinook database from read-only location
local_chinook = sqlite3.connect('./chinook.sqlite') # create a local copy of the chinook database on my system. 

read_only_chinook.backup(local_chinook) # use the backup feature to compy all data from the read-only database to my local file. 
read_only_chinook.close() # close both database connections to complete the operation. 
local_chinook.close()

# %%
# %%sql sqlite:///./chinook.sqlite
# Select *
# From Artist
# Limit 5;
# Out:
# Done.
# [(1, 'AC/DC'),
#  (2, 'Accept'),
#  (3, 'Aerosmith'),
#  (4, 'Alanis Morissette'),
#  (5, 'Alice In Chains')]

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to the local Chinook database
# Select *                        # select all columns
# From Artist                     # query the Artist table to view artist information
# Limit 5;                        # limit the results to the first 5 rows

# %% [markdown]
# ## Question 2
#  - 2.1. Create a new table called "MyPlayers",
#  - 2.2. Insert a single new player into the "MyPlayers" table using the INSERT INTO command,
#  - 2.3. Insert multiple players into the "MyPlayers" table using the INSERT INTO command,
#  - 2.4. Insert all players from the "Master" table into the "MyPlayers" table using the INSERT INTO` command,
#  - 2.5. Query the first 5 rows of the "MyPlayers" table.

# %%
# %%sql sqlite:///./lahman.db
# CREATE TABLE myPlayers (
#     playerID TEXT PRIMARY KEY,
#     name TEXT NOT NULL,
#     teamID TEXT NOT NULL
#     );
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# CREATE TABLE myPlayers (      # create a new table named myPlayers
#     playerID TEXT PRIMARY KEY,  # playerID column set as the primary key with text data type
#     name TEXT NOT NULL,         # name column stores player names and cannot be NULL
#     teamID TEXT NOT NULL        # teamID column stores the team identifier and cannot be NULL
#     );

# %%
# %%sql sqlite:///./lahman.db
# CREATE TABLE myPlayers2 (
#     playerID TEXT PRIMARY KEY,
#     name TEXT NOT NULL,
#     teamID TEXT NOT NULL
#     );
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# CREATE TABLE myPlayers2 (      # create a new table named myPlayers2
#     playerID TEXT PRIMARY KEY,  # playerID column set as the primary key with text data type
#     name TEXT NOT NULL,         # name column stores player names and cannot be NULL
#     teamID TEXT NOT NULL        # teamID column stores the team identifier and cannot be NULL
#     );

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO myPlayers (playerID, name, teamID)
# VALUES ('player1', 'John Doe', 'team1');
# Out:
# 1 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# INSERT INTO myPlayers (playerID, name, teamID)  # insert a new record into myPlayers table
# VALUES ('player1', 'John Doe', 'team1');          # values for playerID, name, and teamID columns

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO myPlayers2 (playerID, name, teamID)
# VALUES ('player1', 'John Doe', 'team1');
# Out:
# 1 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# INSERT INTO myPlayers2 (playerID, name, teamID)  # insert a new record into myPlayers2 table
# VALUES ('player1', 'John Doe', 'team1');          # values for playerID, name, and teamID columns

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From myPlayers
# ;
# Out:
# Done.
# [('player1', 'John Doe', 'team1')]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                  # select all columns
# From myPlayers            # query rows from the myPlayers table
# ;

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From myPlayers2
# ;
# Out:
# Done.
# [('player1', 'John Doe', 'team1')]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                  # select all columns
# From myPlayers2            # query rows from the myPlayers2 table
# ;

# %%
# %%sql sqlite:///./chinook.sqlite
# CREATE TABLE myPlaylists (
#     playlistID TEXT PRIMARY KEY,
#     name TEXT NOT NULL,
#     description TEXT,
#     created_date TEXT
# );
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to the local Chinook database
# CREATE TABLE myPlaylists (      # create a new table named myPlaylists
#     playlistID TEXT PRIMARY KEY,  # playlistID column as primary key with text data type
#     name TEXT NOT NULL,            # name column to store playlist names, cannot be NULL
#     description TEXT,              # description column stores text, can be NULL
#     created_date TEXT              # created_date column stores creation date as text
# );

# %%
# %%sql sqlite:///./chinook.sqlite
# INSERT INTO myPlaylists (playlistID, name, description, created_date)
# VALUES  -- specify values for each new playlist entry
# ('playlist1', 'My Favorites', 'Songs I Love the Most', '2025-01-02'),
# ('playlist2', 'Workout Music', 'High Energy Songs', '2025-01-02'),
# ('playlist3', 'Study Music', 'Calm Symphonic Music', '2025-01-03');
# Out:
# 3 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to the local Chinook database
# INSERT INTO myPlaylists (playlistID, name, description, created_date)  # insert multiple rows into myPlaylists table
# VALUES  -- specify values for each new playlist entry
# ('playlist1', 'My Favorites', 'Songs I Love the Most', '2025-01-02'),  # first playlist details
# ('playlist2', 'Workout Music', 'High Energy Songs', '2025-01-02'),   # second playlist details
# ('playlist3', 'Study Music', 'Calm Symphonic Music', '2025-01-03');   # third playlist details

# %%
# %%sql sqlite:///./chinook.sqlite
# Select *
# From myPlaylists
# ;
# Out:
# Done.
# [('playlist1', 'My Favorites', 'Songs I Love the Most', '2025-01-02'),
#  ('playlist2', 'Workout Music', 'High Energy Songs', '2025-01-02'),
#  ('playlist3', 'Study Music', 'Calm Symphonic Music', '2025-01-03')]

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to the local Chinook database
# Select *                        # select all columns
# From myPlaylists                # query data from the myPlaylists table
# ;                              # end of SQL statement

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO myPlayers(
#     playerID, name, teamID)
# Select p.playerID,
#        p.nameFirst || ' ' || p.nameLast as PlayerName,
#        MIN(s.teamID)
# From People p
# join Salaries s
# on s.playerID = p.playerID
# Where s.yearID =
# (Select MAX(yearID)
#  From Salaries s2
#  Where s2.playerID = s.playerID)
# Group By p.playerID;
# Out:
# 5149 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# INSERT INTO myPlayers(            # insert data into myPlayers table
#     playerID, name, teamID)      # specify columns playerID, name, teamID
# Select p.playerID,               # select playerID from People
#        p.nameFirst || ' ' || p.nameLast as PlayerName,  # concatenate first and last names as PlayerName
#        MIN(s.teamID)             # choose minimum teamID (earliest team) from Salaries
# From People p                   # from People table alias p
# join Salaries s                # join Salaries table alias s on playerID match
# on s.playerID = p.playerID
# Where s.yearID =               # filter for Salaries records with the max yearID per player
# (Select MAX(yearID)
#  From Salaries s2
#  Where s2.playerID = s.playerID)
# Group By p.playerID;           # group results by playerID to aggregate team info

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From myPlayers
# Limit 5;
# Out:
# Done.
# [('player1', 'John Doe', 'team1'),
#  ('aardsda01', 'David Aardsma', 'NYA'),
#  ('aasedo01', 'Don Aase', 'NYN'),
#  ('abadan01', 'Andy Abad', 'CIN'),
#  ('abadfe01', 'Fernando Abad', 'MIN')]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                   # select all columns
# From myPlayers             # fetch all rows from myPlayers table
# Limit 5;                  # limit to first 5 rows of result set

# %%
# %%sql sqlite:///./chinook.sqlite
# INSERT INTO myPlaylists (
#     playlistID, name, description, created_date)
# Select 'playlist_' ||
#     CAST(AlbumID as TEXT),
#     TITLE,
#     'Album Playlist',
#     '2025-01-02'
#     From Album
#     Where AlbumID IN (1, 2, 3, 4, 5);
# Out:
# 5 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to the local Chinook database
# INSERT INTO myPlaylists (        # insert new rows into myPlaylists table
#     playlistID, name, description, created_date)  # specify columns to insert data into
# Select 'playlist_' ||             # concatenate 'playlist_' with AlbumID converted to text as playlistID
#     CAST(AlbumID as TEXT),       # cast AlbumID to text for concatenation
#     TITLE,                       # use the album's title for the name
#     'Album Playlist',            # fixed description text for all inserted playlists
#     '2025-01-02'                 # fixed creation date for all inserted rows
#     From Album                   # select rows from the Album table
#     Where AlbumID IN (1, 2, 3, 4, 5);  # filter albums with AlbumID in the specified list

# %%
# %%sql sqlite:///./chinook.sqlite
# Select *
# From myPlaylists
# Limit 5;
# Out:
# Done.
# [('playlist1', 'My Favorites', 'Songs I Love the Most', '2025-01-02'),
#  ('playlist2', 'Workout Music', 'High Energy Songs', '2025-01-02'),
#  ('playlist3', 'Study Music', 'Calm Symphonic Music', '2025-01-03'),
#  ('playlist_1', 'For Those About To Rock We Salute You', 'Album Playlist', '2025-01-02'),
#  ('playlist_2', 'Balls to the Wall', 'Album Playlist', '2025-01-02')]

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to the local Chinook database
# Select *                        # select all columns
# From myPlaylists                # query all rows from myPlaylists table
# Limit 5;                       # limit output to the first 5 rows

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From People
# Limit 5;
# Out:
# Done.
# [('aardsda01', 1981, 12, 27, 'Denver', 'USA', 'CO', '', '', '', '', '', '', 'David', 'Aardsma', 'David Allan', 215, 75, 'R', 'R', '2004-04-06', 'aardsda01', '2015-08-23', 'aardd001'),
#  ('aaronha01', 1934, 2, 5, 'Mobile', 'USA', 'AL', 2021, 1, 22, 'USA', 'GA', 'Atlanta', 'Hank', 'Aaron', 'Henry Louis', 180, 72, 'R', 'R', '1954-04-13', 'aaronha01', '1976-10-03', 'aaroh101'),
#  ('aaronto01', 1939, 8, 5, 'Mobile', 'USA', 'AL', 1984, 8, 16, 'USA', 'GA', 'Atlanta', 'Tommie', 'Aaron', 'Tommie Lee', 190, 75, 'R', 'R', '1962-04-10', 'aaronto01', '1971-09-26', 'aarot101'),
#  ('aasedo01', 1954, 9, 8, 'Orange', 'USA', 'CA', '', '', '', '', '', '', 'Don', 'Aase', 'Donald William', 190, 75, 'R', 'R', '1977-07-26', 'aasedo01', '1990-10-03', 'aased001'),
#  ('abadan01', 1972, 8, 25, 'Palm Beach', 'USA', 'FL', '', '', '', '', '', '', 'Andy', 'Abad', 'Fausto Andres', 184, 73, 'L', 'L', '2001-09-10', 'abadan01', '2006-04-13', 'abada001')]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                    # select all columns
# From People                 # query all rows from the People table
# Limit 5;                   # limit output to the first 5 rows

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO myPlayers2(
#     playerID, name, teamID)
# Select
#     p.playerID,
#     p.nameFirst || ' ' || p.nameLast AS name,
#     MIN(b.teamID) as teamID
# From People p
# join Batting b
#     on b.playerID = p.playerID
# where b.yearID
# = (select b2.yearID
#    from Batting b2
#    where b2.yearID between 1871 and 2023)
# group by p.playerID;
# Out:
# (sqlite3.IntegrityError) UNIQUE constraint failed: myPlayers2.playerID
# [SQL: INSERT INTO myPlayers2(
#     playerID, name, teamID)
# Select
#     p.playerID,
#     p.nameFirst || ' ' || p.nameLast AS name,
#     MIN(b.teamID) as teamID
# From People p
# join Batting b
#     on b.playerID = p.playerID
# where b.yearID
# = (select b2.yearID
#    from Batting b2
#    where b2.yearID between 1871 and 2023)
# group by p.playerID;]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# INSERT INTO myPlayers2(                # insert data into myPlayers2 table
#     playerID, name, teamID)           # specify columns playerID, name, teamID
# Select
#     p.playerID,                      # select playerID from People
#     p.nameFirst || ' ' || p.nameLast AS name,  # concatenate first and last names as name
#     MIN(b.teamID) as teamID          # select the minimum teamID from Batting as teamID
# From People p                      # from People table alias p
# join Batting b                    # join Batting table alias b on playerID
#     on b.playerID = p.playerID
# where b.yearID                    # filter for batting records in year range 1871 to 2023 (this part needs correction)
# = (select b2.yearID              # subquery for yearID from Batting as b2 within the given range
#    from Batting b2
#    where b2.yearID between 1871 and 2023)
# group by p.playerID;             # group results by playerID to aggregate team info

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From myPlayers2
# Limit 5;
# Out:
# Done.
# [('player1', 'John Doe', 'team1'),
#  ('aardsda01', 'David Aardsma', 'SFN'),
#  ('abbotpa01', 'Paul Abbott', 'PHI'),
#  ('abreubo01', 'Bobby Abreu', 'PHI'),
#  ('acevejo01', 'Jose Acevedo', 'CIN')]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                    # select all columns from the table
# From myPlayers2             # query data from the myPlayers2 table
# Limit 5;                   # limit the output to the first 5 rows only

# %% [markdown]
# ## Question 3
#
#  - 3.1. Alter the "MyPlayers" table to add a new column called "height" of type REAL,
#  - 3.2. Alter the "MyPlayers" table to add a new column called "weight" of type REAL,
#  - 3.3. Insert a new player into the "MyPlayers" table with the specified data,
#  - 3.4. Query the "MyPlayers" table to return the 5 tallest players, ordered by height in descending order.

# %%
# %%sql sqlite:///./lahman.db
# ALTER TABLE myPlayers
# ADD COLUMN height REAL;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to local Lahman database
# ALTER TABLE myPlayers         # modify the myPlayers table
# ADD COLUMN height REAL;       # add a new column named 'height' with type real

# %%
# %%sql sqlite:///./lahman.db
# ALTER TABLE myPlayers2
# ADD COLUMN height REAL;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to local Lahman database
# ALTER TABLE myPlayers2         # modify the myPlayers2 table
# ADD COLUMN height REAL;       # add a new column named 'height' with type real

# %%
# %%sql sqlite:///./lahman.db
# ALTER TABLE myPlayers
# ADD COLUMN weight REAL;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# ALTER TABLE myPlayers         # modify the myPlayers table
# ADD COLUMN weight REAL;       # add a new column named 'weight' with type real

# %%
# %%sql sqlite:///./lahman.db
# ALTER TABLE myPlayers2
# ADD COLUMN weight REAL;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# ALTER TABLE myPlayers2       # modify the myPlayers2 table
# ADD COLUMN weight REAL;       # add a new column named 'weight' with type real

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO myPlayers (playerID, name, teamID, height, weight)
# VALUES
# ('player2', 'Stephen Kimiya', 'team2', 67, 110),
# ('player3', 'Jackie Aeko', 'team3', 65, 103),
# ('player4', 'Muhammad Yakni', 'team3', 71, 121),
# ('player5', 'Sarah Adan', 'team2', 73, 144),
# ('player6', 'Shawn Emeline', 'team2', 75, 178);
# Out:
# 5 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# INSERT INTO myPlayers (playerID, name, teamID, height, weight)  # insert multiple rows into myPlayers table with height and weight data
# VALUES
# ('player2', 'Stephen Kimiya', 'team2', 67, 110),               # second player's data including height and weight
# ('player3', 'Jackie Aeko', 'team3', 65, 103),                  # third player's data
# ('player4', 'Muhammad Yakni', 'team3', 71, 121),               # fourth player's data
# ('player5', 'Sarah Adan', 'team2', 73, 144),                   # fifth player's data
# ('player6', 'Shawn Emeline', 'team2', 75, 178);                # sixth player's data

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From myPlayers
# order by height desc
# limit 5;
# Out:
# Done.
# [('player6', 'Shawn Emeline', 'team2', 75.0, 178.0),
#  ('player5', 'Sarah Adan', 'team2', 73.0, 144.0),
#  ('player4', 'Muhammad Yakni', 'team3', 71.0, 121.0),
#  ('player2', 'Stephen Kimiya', 'team2', 67.0, 110.0),
#  ('player3', 'Jackie Aeko', 'team3', 65.0, 103.0)]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                    # select all columns from the table
# From myPlayers              # query all records from the myPlayers table
# order by height desc        # order the results by the height column in descending order
# limit 5;                   # limit output to the top 5 rows after sorting

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO myPlayers2 (playerID, name, teamID, height, weight)
# VALUES
# ('player2', 'Kimiya Stephen', 'team2', 55, 90),
# ('player3', 'Aeko Jackie', 'team3', 57, 80),
# ('player4', 'Yakni Muhammad', 'team3', 50, 101),
# ('player5', 'Adan Sarah', 'team2', 48, 111),
# ('player6', 'Emeline Stephen', 'team2', 41, 131);
# Out:
# 5 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# INSERT INTO myPlayers2 (playerID, name, teamID, height, weight)  # insert multiple rows into myPlayers2 table with height and weight values
# VALUES
# ('player2', 'Kimiya Stephen', 'team2', 55, 90),                 # second row with player details
# ('player3', 'Aeko Jackie', 'team3', 57, 80),                    # third row with player details
# ('player4', 'Yakni Muhammad', 'team3', 50, 101),                # fourth row with player details
# ('player5', 'Adan Sarah', 'team2', 48, 111),                    # fifth row data
# ('player6', 'Emeline Stephen', 'team2', 41, 131);               # sixth row data

# %%
# %%sql sqlite:///./lahman.db
# Select
# *
# From myPlayers2
# order by height desc
# limit 5;
# Out:
# Done.
# [('player3', 'Aeko Jackie', 'team3', 57.0, 80.0),
#  ('player2', 'Kimiya Stephen', 'team2', 55.0, 90.0),
#  ('player4', 'Yakni Muhammad', 'team3', 50.0, 101.0),
#  ('player5', 'Adan Sarah', 'team2', 48.0, 111.0),
#  ('player6', 'Emeline Stephen', 'team2', 41.0, 131.0)]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select                     # select columns
# *                          # all columns from the table
# From myPlayers2             # query the myPlayers2 table
# order by height desc        # order results by height in descending order
# limit 5;                   # limit output to top 5 rows

# %% [markdown]
# ## Question 4
#
#  - 4.1. Delete a player from the "MyPlayers" table using the DELETE command,
#  - 4.2. Delete all players from the "MyPlayers" table that have a height less than 6 feet using the DELETE command,
#  - 4.3. Query the "MyPlayers" table to verify that the players have been deleted.

# %%
# %%sql sqlite:///./lahman.db
# DELETE FROM MyPlayers
# WHERE playerID = 'player1';
# Out:
# 1 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# DELETE FROM MyPlayers         # delete rows from MyPlayers table
# WHERE playerID = 'player1';   # only delete the row where playerID equals 'player1'

# %%
# %%sql sqlite:///./lahman.db
# DELETE FROM myPlayers
# WHERE height < 72;
# Out:
# 3 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# DELETE FROM myPlayers         # delete rows from myPlayers table
# WHERE height < 72;            # delete rows where height is less than 72

# %%
# %%sql sqlite:///./lahman.db
# DELETE FROM myPlayers2
# WHERE playerID in ('player1','player2', 'player3', 'player4', 'player5','player6');
# Out:
# 6 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# DELETE FROM myPlayers2        # delete rows from myPlayers2 table
# WHERE playerID in ('player1','player2', 'player3', 'player4', 'player5','player6');  # delete rows where playerID matches any of the listed values

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From myPlayers
# order by height desc
# limit 5;
# Out:
# Done.
# [('player6', 'Shawn Emeline', 'team2', 75.0, 178.0),
#  ('player5', 'Sarah Adan', 'team2', 73.0, 144.0),
#  ('aardsda01', 'David Aardsma', 'NYA', None, None),
#  ('aasedo01', 'Don Aase', 'NYN', None, None),
#  ('abadan01', 'Andy Abad', 'CIN', None, None)]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                    # select all columns from the table
# From myPlayers              # query all rows from the myPlayers table
# order by height desc        # order the results by height in descending order
# limit 5;                   # limit output to the top 5 rows after sorting

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From myPlayers2
# order by height desc
# limit 5;
# Out:
# Done.
# [('aardsda01', 'David Aardsma', 'SFN', None, None),
#  ('abbotpa01', 'Paul Abbott', 'PHI', None, None),
#  ('abreubo01', 'Bobby Abreu', 'PHI', None, None),
#  ('acevejo01', 'Jose Acevedo', 'CIN', None, None),
#  ('adamsmi03', 'Mike Adams', 'MIL', None, None)]

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                    # select all columns from the table
# From myPlayers2              # query all rows from the myPlayers2 table
# order by height desc        # order the results by height in descending order
# limit 5;                   # limit output to the top 5 rows after sorting

# %% [markdown]
# Question 5
#  - 5.1. Remove all data from the "MyPlayers" table using the DELETE command,
#  - 5.2. Drop the "MyPlayers" table using the DROP TABLE command,
#  - 5.3. Verify that the "MyPlayers" table has been dropped by attempting to query it.

# %%
# %%sql sqlite:///./lahman.db
# delete from myPlayers2
# ;
# delete from myPlayers
# ;
# Out:
# 1247 rows affected.
# 5151 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# delete from myPlayers2        # delete all rows from myPlayers2 table
# ;
# delete from myPlayers         # delete all rows from myPlayers table
# ;

# %%
# %%sql sqlite:///./chinook.sqlite
# DELETE FROM Artist;
# Out:
# 275 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite
# DELETE FROM Artist;   # deletes all rows from the Artist table in the Chinook database

# %%
# %%sql sqlite:///./lahman.db
# DROP TABLE myPlayers;
# DROP TABLE myPlayers2;
# Out:
# Done.
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# DROP TABLE myPlayers;      # permanently delete the myPlayers table and all its data
# DROP TABLE myPlayers2;     # permanently delete the myPlayers2 table and all its data

# %%
# %%sql sqlite:///./lahman.db
# DROP TABLE myPlayers2;
# Out:
# (sqlite3.OperationalError) no such table: myPlayers2
# [SQL: DROP TABLE myPlayers2;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# DROP TABLE myPlayers2;      # permanently delete the myPlayers2 table and all its contents

# %%
# %%sql sqlite:///./chinook.sqlite
# DROP TABLE Chinook;
# Out:
# (sqlite3.OperationalError) no such table: Chinook
# [SQL: DROP TABLE Chinook;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to the local Chinook database
# DROP TABLE Chinook;       # attempt to drop the Chinook db

# %%
# %%sql sqlite:///./lahman.db
# Select
# *
# From myPlayers
# limit 5;
# Out:
# (sqlite3.OperationalError) no such table: myPlayers
# [SQL: Select
# *
# From myPlayers
# limit 5;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                    # select all columns from the table
#
# From myPlayers              # query all rows from the myPlayers table
# limit 5;                   # limit the output to the first 5 rows only

# %%
# %%sql sqlite:///./lahman.db
# Select *
#
# From myPlayers2
# limit 5;
# Out:
# (sqlite3.OperationalError) no such table: myPlayers2
# [SQL: Select *
#
# From myPlayers2
# limit 5;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# %%sql sqlite:///./lahman.db  # connect to the local Lahman database
# Select *                    # select all columns from the table
#
# From myPlayers2              # query all rows from the myPlayers2 table
# limit 5;                   # limit the output to the first 5 rows only

# %%
# %%sql sqlite:///./chinook.sqlite
# Select
# *
# From Chinook
# Out:
# (sqlite3.OperationalError) no such table: Chinook
# [SQL: Select
# *
# From Chinook]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# %%sql sqlite:///./chinook.sqlite  # connect to local Chinook database
# Select *                     # all columns from the table
#
# From Chinook                # attempt to select rows from a

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
