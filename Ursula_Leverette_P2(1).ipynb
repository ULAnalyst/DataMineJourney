# %% [markdown]
# # Project 3 -- Ursula Leverette

# %% [markdown]
# **TA Help:** Michael Hanson(Q4), Ruiming Xu(Q5)
#
# **Question 4**
#     - Remove ">" when cp reviews.csc to $SCRATCH/myfolder
#     - change "F" in myFolder to "f" in my folder to match the folder name declared in mkdir
# **Question 5**
#     - Reset question 5 to beginning
#     - recreate mydinner in HOME directory
#     - remove mydinner# from HOME directory
#     - remove file path .txt from echo
#     - mv mydinner to SCRATCH/mybreakfast
#
#
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).
#
# ## Question 1
#
#
#
#
#     Write a bash command to display both your home directory ($HOME) and your current working directory (pwd). These two directories should be the same. Ensure you run the command in the terminal immediately after opening it, without making any changes to the home directory sidebar.
#
#     Write a bash command to change your current directory to /anvil/projects/tdm/data using cd command.
#
#     Run the same command from Step 1 above again.
#
#     Explain any observations you see in the results from Step 1 and Step 2. Explain the difference between $HOME and pwd.

# %%
# !echo $HOME # print home directory(display the home directory path/location)
# Out:
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# pwd # print working directory
# Out:
# /home/x-uleverette

# %%
# %pwd #print the directory I am currently working in
# Out:
# '/home/x-uleverette'

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data  # cd = change directory into the file path/directory as defined
# !echo $HOME # print by displaying home directory
# pwd # # print the directory I am currently working in
# Out:
# bash: line 3: !echo: command not found
# /anvil/projects/tdm/data

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 2
#
#
#     Write a bash command to change your current directory to /anvil/projects/tdm/data/zillow using cd command.
#
#     Run each of the commands individually and print the current working directory for parts a–d. After executing each command, make sure to return to the /anvil/projects/tdm/data/zillow directory. Explain the functionality of each command based on your observations.
#
#         cd
#
#         cd .
#
#         cd ..
#
#         cd ../../
#
#         ls or ls . show the list of contents in the absolute currently defined directory we are in
#
#         ls -la or ls -la .
#
#         ls ../ combined with cd / the ls .. command is relative and operates in a similar method as cd .. show the list of contents relative to the command indicating look at           the contents up one from the current defined path/directory.

# %%
# !echo $HOME
# Out:
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# pwd # print working directory
# Out:
# /anvil/projects/tdm/data/zillow

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd # change from zillow directory to HOME directory
# pwd # print working directory
# Out:
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd . # change directory to current zillow directory
# pwd # print working directory
# Out:
# /anvil/projects/tdm/data/zillow

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.
# cd /anvil/projects/tdm/data/ # cd = change to the data directory following the file path as defined
# pwd # prints working directory
# Out:
# /anvil/projects/tdm/data

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd .. # change directory up one from zillow to data
# cd ..  # change directory up one from data to tdm
# pwd # print working directory
# Out:
# /anvil/projects/tdm

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# #cd .. # change directory up one from zillow to data
# #cd ..  # change directory up one from data to tdm
# ls # ls = show contents in the directory -la = size of files with dates
# pwd # print working directory
# Out:
# City_time_series.csv
# CountyCrossWalk_Zillow.csv
# County_time_series.csv
# DataDictionary.csv
# Metro_time_series.csv
# Neighborhood_time_series.csv
# State_time_series.csv
# Zip_time_series.csv
# all_available_metrics.json
# cities_crosswalk.csv
# fields_per_level.json
# /anvil/projects/tdm/data/zillow

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd .. # change directory up one from zillow to data
# #cd ..  # change directory up one from data to tdm
# ls # ls = show contents in the directory -la = size of files with dates
# pwd # print working directory
# Out:
# 8451
# CMS
# DELETE_house-prices
# DELETE_wine
# aiannh
# airbnb
# amazon
# apple
# archive
# bay_area_bike_share
# beer
# bosch
# boston_housing
# boundaries
# chinook
# co2
# coco
# concrete_crack_data_tfrecords
# concrete_cracks_mini
# consumer_complaints
# craigslist
# death_records
# disney
# donorschoose
# election
# expedia
# fao
# fars
# fips
# flights
# forest
# goodreads
# grouping
# hidden
# icecream
# images
# iowa_liquor_sales
# iris
# lahman
# mortgage_rates
# movies_and_tv
# noaa
# noaa_timeseries
# noaa_timeseries2
# nps
# nyc
# okcupid
# olympics
# open_food_facts
# otc
# precip
# project05
# project09
# ravdess
# restaurant
# scavenger_hunt
# shopper_intention
# sim
# social_media_addiction
# spotify
# stackoverflow
# starwars
# taxi
# techcrunch
# tippecanoe
# whin
# wine_quality
# worldbank
# yelp
# youtube
# zillow
# /anvil/projects/tdm/data

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd .. # change directory up one from zillow to data
# cd ..  # change directory up one from data to tdm
# ls # ls = show contents in the directory -la = size of files with dates
# pwd # print working directory
# Out:
# DELETE
# apps
# archive
# backups
# bin
# corporate
# corporate_old
# dashboard
# data
# etc
# log
# notebooks
# opt
# research
# seminar
# sps
# tmp
# /anvil/projects/tdm

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# #cd .. # change directory up one from zillow to data
# #cd ..  # change directory up one from data to tdm
# ls -la # ls = show contents in the directory -la = size of files with dates
# pwd # print working directory
# Out:
# total 1871363
# drwxrwsr-x+  2 nobody nogroup      4096 Aug  5  2023 .
# drwxrwsr-x+ 74 nobody nogroup      4096 Aug 11 16:42 ..
# -rw-r--r--   1 nobody nogroup 689627012 Sep 21  2019 City_time_series.csv
# -rw-r--r--   1 nobody nogroup    232467 Sep 21  2019 CountyCrossWalk_Zillow.csv
# -rw-r--r--   1 nobody nogroup 112778579 Sep 21  2019 County_time_series.csv
# -rw-r--r--   1 nobody nogroup      4668 Sep 21  2019 DataDictionary.csv
# -rw-r--r--   1 nobody nogroup  56232114 Sep 21  2019 Metro_time_series.csv
# -rw-r--r--   1 nobody nogroup 265790699 Sep 21  2019 Neighborhood_time_series.csv
# -rw-r--r--   1 nobody nogroup   4742679 Sep 21  2019 State_time_series.csv
# -rw-r--r--   1 nobody nogroup 782137407 Sep 21  2019 Zip_time_series.csv
# -rw-r--r--   1 nobody nogroup      3409 Sep 21  2019 all_available_metrics.json
# -rw-r--r--   1 nobody nogroup   1074309 Sep 21  2019 cities_crosswalk.csv
# -rw-r--r--   1 nobody nogroup     17005 Sep 21  2019 fields_per_level.json
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd .. # change directory up one from zillow to data
# #cd ..  # change directory up one from data to tdm
# ls -la # ls = show contents in the directory -la = size of files with dates
# pwd # print working directory
# Out:
# total 275
# drwxrwsr-x+ 74 nobody nogroup  4096 Aug 11 16:42 .
# drwxrwsr-x+ 20 nobody nogroup  8192 Aug 20 09:47 ..
# drwxrwsr-x+  2 nobody nogroup  4096 May 20 09:24 .ipynb_checkpoints
# drwxrwsr-x+  4 nobody nogroup  4096 Sep  1  2019 8451
# drwxrwsr-x+  4 nobody nogroup  4096 Jul 23 08:05 CMS
# drwxr-sr-x+  2 nobody nogroup  4096 Jun 11  2024 DELETE_house-prices
# drwxr-sr-x+  2 nobody nogroup  4096 Jun 11  2024 DELETE_wine
# drwxrwsr-x+  2 nobody nogroup  4096 Mar 23 16:13 aiannh
# drwxrwsr-x+ 36 nobody nogroup  8192 Jul 24  2023 airbnb
# drwxrwsr-x+  4 nobody nogroup  4096 Mar 11  2024 amazon
# drwxrwsr-x+  3 nobody nogroup  4096 Jan 14  2021 apple
# drwxrwsr-x+  3 nobody nogroup  4096 May 20 09:28 archive
# drwxrwsr-x+  4 nobody nogroup 16384 Jul 28  2023 bay_area_bike_share
# drwxrwsr-x+  2 nobody nogroup  4096 Apr  1  2024 beer
# drwxrwsr-x+  2 nobody nogroup  4096 Jan  7  2022 bosch
# drwxrwsr-x+  2 nobody nogroup  4096 Jul 29  2024 boston_housing
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd .. # change directory up one from zillow to data
# cd ..  # change directory up one from data to tdm
# ls -la # ls = show contents in the directory -la = size of files with dates
# pwd # print working directory
# Out:
# total 447
# drwxrwsr-x+   20 nobody nogroup   8192 Aug 20 09:47 .
# drwxr-sr-x  1351 nobody nogroup  65536 Sep  5 16:50 ..
# drwxrwsr-x+    2 nobody nogroup   4096 Feb 20  2025 .ipynb_checkpoints
# drwxrws---+    7 nobody nogroup   4096 Jul 21 13:15 DELETE
# drwxrwsr-x+   17 nobody nogroup   4096 Feb 28  2025 apps
# drwxrwsr-x+    4 nobody nogroup   4096 Aug 30  2023 archive
# drwxrws---+    4 nobody nogroup   4096 Jul 11  2022 backups
# drwxrwsr-x+    5 nobody nogroup   8192 Sep  4 16:09 bin
# drwxrwsr-x+   98 nobody nogroup   8192 Sep  2 15:58 corporate
# drwxrwsr-x+    4 nobody nogroup 131072 Aug 15 16:39 corporate_old
# drwxrwx---+    5 nobody nogroup   4096 Jun 11 07:05 dashboard
# drwxrwsr-x+   74 nobody nogroup   4096 Aug 11 16:42 data
# drwxrwsr-x+   13 nobody nogroup   4096 Sep 30  2023 etc
# drwxrws---+    4 nobody nogroup   4096 Sep  6 09:55 log
# drwxrwsr-x+    9 nobody nogroup   4096 Mar 25 13:03 notebooks
# drwxrwsr-x+    9 nobody nogroup   4096 Aug  7  2024 opt
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# #cd .. # change directory up one from zillow to data
# #cd ..  # change directory up one from data to tdm
# ls .. # ls .. = look at the contents in the directory up one from zillow to data directory
# pwd # print working directory
# Out:
# 8451
# CMS
# DELETE_house-prices
# DELETE_wine
# aiannh
# airbnb
# amazon
# apple
# archive
# bay_area_bike_share
# beer
# bosch
# boston_housing
# boundaries
# chinook
# co2
# coco
# concrete_crack_data_tfrecords
# concrete_cracks_mini
# consumer_complaints
# craigslist
# death_records
# disney
# donorschoose
# election
# expedia
# fao
# fars
# fips
# flights
# forest
# goodreads
# grouping
# hidden
# icecream
# images
# iowa_liquor_sales
# iris
# lahman
# mortgage_rates
# movies_and_tv
# noaa
# noaa_timeseries
# noaa_timeseries2
# nps
# nyc
# okcupid
# olympics
# open_food_facts
# otc
# precip
# project05
# project09
# ravdess
# restaurant
# scavenger_hunt
# shopper_intention
# sim
# social_media_addiction
# spotify
# stackoverflow
# starwars
# taxi
# techcrunch
# tippecanoe
# whin
# wine_quality
# worldbank
# yelp
# youtube
# zillow
# /anvil/projects/tdm/data/zillow

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd .. # change directory up one from zillow to data
# #cd ..  # change directory up one from data to tdm
# ls ../ # ls .. = look contents in the directory up one from data to tdm directory
# pwd # print working directory
# Out:
# DELETE
# apps
# archive
# backups
# bin
# corporate
# corporate_old
# dashboard
# data
# etc
# log
# notebooks
# opt
# research
# seminar
# sps
# tmp
# /anvil/projects/tdm/data

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/zillow/ # cd = change directory into the file path/directory as defined
# cd .. # change directory up one from zillow to data
# cd ..  # change directory up one from data to tdm
# ls ../ # ls .. = look contents in the directory up one from tdm to projects directory
# pwd # print working directory
# Out:
# ai240101
# ai240112
# ai240141
# ai240246
# ai240262
# ai240289
# ai240335
# ai240337
# ai240382
# ai240400
# ai240405
# ai240428
# ai240462
# ai250014
# ai250035
# ai250052
# ai250070
# ai250073
# ai250076
# ai250083
# ai250094
# ai250095
# ai250100
# ai250101
# ai250102
# ai250105
# ai250124
# ai250128
# hpcdata
# irvine
# itap
# nwp
# pur230001
# pur230003
# pur230004
# pur230005
# pur230006
# pur230007
# pur230008
# pur230009
# pur230010
# pur230011
# rcacdata
# slurm
# tdm
# x-agr230027
# x-agr240009
# x-agr240010
# x-agr240020
# x-agr240032
# x-agr250001
# x-agr250004
# x-agr250013
# x-agr250014
# x-asc150002
# x-asc160051
# x-asc160064
# x-asc170016
# x-asc170035
# x-asc170037
# x-asc180023
# x-asc180050
# x-asc190064
# x-asc200042
# x-ast050018
# x-ast080028
# x-ast100035
# x-ast120060
# x-ast120062
# x-ast120067
# x-ast140008
# x-ast140041
# x-ast180008
# x-ast180056
# x-ast190018
# x-ast190019
# x-ast200002
# x-ast200014
# x-ast200017
# x-ast200032
# x-atm100026
# ...

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 3
#
#
#     Go to /anvil/projects/tdm/data/icecream/breyers
#
#     Print the first five rows of reviews.csv using head
#
#     Print the last five rows of reviews.csv using tail
#
#     Print only column names (first row) of reviews.csv using -n option
#
#     Run wc reviews.csv and identify which parts of the output represent what information
#
#     Get the line count only for the given file using the -l option
#
# Relevant topics: head, tail, wc

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/icecream
# ls # absolute show the contents of the icecream directory
# pwd # print working directory
# Out:
# bj
# breyers
# combined
# hd
# icecream.png
# talenti
# /anvil/projects/tdm/data/icecream

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/icecream
# ls .. # relative go up one level to look at the contents of the data directory.
# pwd # print working directory
# Out:
# 8451
# CMS
# DELETE_house-prices
# DELETE_wine
# aiannh
# airbnb
# amazon
# apple
# archive
# bay_area_bike_share
# beer
# bosch
# boston_housing
# boundaries
# chinook
# co2
# coco
# concrete_crack_data_tfrecords
# concrete_cracks_mini
# consumer_complaints
# craigslist
# death_records
# disney
# donorschoose
# election
# expedia
# fao
# fars
# fips
# flights
# forest
# goodreads
# grouping
# hidden
# icecream
# images
# iowa_liquor_sales
# iris
# lahman
# mortgage_rates
# movies_and_tv
# noaa
# noaa_timeseries
# noaa_timeseries2
# nps
# nyc
# okcupid
# olympics
# open_food_facts
# otc
# precip
# project05
# project09
# ravdess
# restaurant
# scavenger_hunt
# shopper_intention
# sim
# social_media_addiction
# spotify
# stackoverflow
# starwars
# taxi
# techcrunch
# tippecanoe
# whin
# wine_quality
# worldbank
# yelp
# youtube
# zillow
# /anvil/projects/tdm/data/icecream

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd /anvil/projects/tdm/data/icecream/breyers/
# ls # absolute show the contents of the breyers directory
# pwd # print working directory
# Out:
# images
# products.csv
# reviews.csv
# /anvil/projects/tdm/data/icecream/breyers

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view first 10 rows of file including column headers
#
# pwd # print working directory
# Out:
# key,author,date,stars,title,helpful_yes,helpful_no,text
# 0_breyers,LABEL READER,2020-04-17,2,EVER INCREASING INGEDIENTS LIST.,81,3,"Not the long ago Breyers set itself apart from other brands by using ONLY MILK, CREAM, SUGAR, and VANILLA in it's Vanilla ice cream. They went so far as to have TV commercials with children reading the ver very simple label. Now they show similar comercials stating the Breyers is made WITH those ingredients but no longer ONLY WITH. Read the label for yourself. The ice cream is still good but the longer ingrediants list ant the missing word ""ONLY"" hasn't gone unnoticed despite the attempt to gloss over the corporate decision to move away from the one distinctive characteristic that set the Breyers brand apart from the others."
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head -n5 /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view first 5 rows of file including column headers
#
# pwd # print working directory
# Out:
# key,author,date,stars,title,helpful_yes,helpful_no,text
# 0_breyers,LABEL READER,2020-04-17,2,EVER INCREASING INGEDIENTS LIST.,81,3,"Not the long ago Breyers set itself apart from other brands by using ONLY MILK, CREAM, SUGAR, and VANILLA in it's Vanilla ice cream. They went so far as to have TV commercials with children reading the ver very simple label. Now they show similar comercials stating the Breyers is made WITH those ingredients but no longer ONLY WITH. Read the label for yourself. The ice cream is still good but the longer ingrediants list ant the missing word ""ONLY"" hasn't gone unnoticed despite the attempt to gloss over the corporate decision to move away from the one distinctive characteristic that set the Breyers brand apart from the others."
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# tail -n5 /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view last 5 rows of file including column headers
#
# pwd # print working directory
# Out:
# 68_breyers,Randi,2020-04-22,1,Terrible missing the chocolate ice cream,0,0,"There was no chocolate ice cream in this at all, this was very very disappointing, didn’t even come close to looking like the package"
# 68_breyers,Bethie,2020-09-08,1,Terrible,0,0,This ice cream has no flavor at all. No one in the entire family liked it. Kids refusing ice cream - for real?
# 68_breyers,Nshaw1994,2020-09-09,5,Flavor of the week!,0,0,Absolutely love this flavor! The only thing that would make it better is caramel and cookie dough bites!
# 68_breyers,PamelaG,2020-06-01,5,Love this flavor!!,0,0,Brilliant combo - love the cheesecake and brownie chunks - please keep making this!!
# 68_breyers,Fanchon,2020-08-22,5,Great,0,0,Has a delicious taste with all natural ingredients
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head -n1 /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view first 1 rows of file including column headers
#
# pwd # print working directory
# Out:
# key,author,date,stars,title,helpful_yes,helpful_no,text
# /home/x-uleverette

# %%
# %%bash
# wc --help
# Out:
# Usage: wc [OPTION]... [FILE]...
#   or:  wc [OPTION]... --files0-from=F
# Print newline, word, and byte counts for each FILE, and a total line if
# more than one FILE is specified.  A word is a non-zero-length sequence of
# printable characters delimited by white space.
#
# With no FILE, or when FILE is -, read standard input.
#
# The options below may be used to select which counts are printed, always in
# the following order: newline, word, character, byte, maximum line length.
#   -c, --bytes            print the byte counts
#   -m, --chars            print the character counts
#   -l, --lines            print the newline counts
#       --files0-from=F    read input from the files specified by
#                            NUL-terminated names in file F;
#                            If F is - then read names from standard input
#   -L, --max-line-length  print the maximum display width
#   -w, --words            print the word counts
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# wc /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view counts = -c byte counts, -m character counts, -l newline counts.
#
# pwd # print working directory
# Out:
#    5464  225282 1436490 /anvil/projects/tdm/data/icecream/breyers/reviews.csv
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# wc -m /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view counts = -c byte counts, -m character counts, -l newline counts.
#
# pwd # print working directory
# Out:
# 1436490 /anvil/projects/tdm/data/icecream/breyers/reviews.csv
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# wc -c /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view counts = -c byte counts, -m character counts, -l newline counts.
#
# pwd # print working directory
# Out:
# 1436490 /anvil/projects/tdm/data/icecream/breyers/reviews.csv
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# wc -l /anvil/projects/tdm/data/icecream/breyers/reviews.csv # view the newline counts of the reviews.csv file.
#
# pwd # print working directory
# Out:
# 5464 /anvil/projects/tdm/data/icecream/breyers/reviews.csv
# /home/x-uleverette

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 4
#
#
#     What are the size limits for your home directory and scratch directory?
#     Home = 25GB
#     Scratch = 100TB
#
#     Copy the reviews.csv file to your SCRATCH directory using cp
#
#     Copy the entire icecream directory to your SCRATCH
#
#     Print the list of files and folders in your SCRATCH directory
#
#     Delete the copied reviews.csv from your SCRATCH
#
#     Delete the copied icecream directory from your SCRATCH
#
#     Print the list of files and folders of your SCRATCH directory again

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# mkdir $SCRATCH/myfolder #mkdir = make directory create a directory inside of $SCRATCH called myfolder
# # rm -r $SCRATCH/myfolder # rm = remove files or directories - r = remove directories and their contents recursively(remove the previously made directory recursively)
# Out:
# total 66
# drwxrwsr-x+  4 nobody nogroup 16384 Jul 28  2023 .
# drwxrwsr-x+ 74 nobody nogroup  4096 Aug 11 16:42 ..
# drwxrwsr-x+  2 nobody nogroup 16384 Aug 24 21:52 baywheels
# drwxrwsr-x+  2 nobody nogroup  4096 Jul 28  2023 kaggle
# /anvil/projects/tdm/data/bay_area_bike_share

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cp /anvil/projects/tdm/data/icecream/breyers/reviews.csv $SCRATCH/myfolder # cp = Copy SOURCE to DEST or Directory defined as $SCRATCH/myfolder

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head $SCRATCH/myfolder/reviews.csv # print first 10 rows of file including column headers
# Out:
# key,author,date,stars,title,helpful_yes,helpful_no,text
# 0_breyers,LABEL READER,2020-04-17,2,EVER INCREASING INGEDIENTS LIST.,81,3,"Not the long ago Breyers set itself apart from other brands by using ONLY MILK, CREAM, SUGAR, and VANILLA in it's Vanilla ice cream. They went so far as to have TV commercials with children reading the ver very simple label. Now they show similar comercials stating the Breyers is made WITH those ingredients but no longer ONLY WITH. Read the label for yourself. The ice cream is still good but the longer ingrediants list ant the missing word ""ONLY"" hasn't gone unnoticed despite the attempt to gloss over the corporate decision to move away from the one distinctive characteristic that set the Breyers brand apart from the others."
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cp -r /anvil/projects/tdm/data/icecream/ $SCRATCH/myfolder # cp = Copy SOURCE to DEST or Directory defined as $SCRATCH/myfolder

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd $SCRATCH/myfolder/ # cd = change directory to $SCRATCH/myfolder diredtory
# ls # list contents in directory ( List information about the FILEs (the current directory by default))
# pwd #  Print the full filename of the current working directory.
# Out:
# icecream
# reviews.csv
# /anvil/scratch/x-uleverette/myfolder

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# rm $SCRATCH/myfolder/reviews.csv # delecte reviews.csv from $SCRATCH/myfolder/ directory
# Out:
# rm: cannot remove '/anvil/scratch/x-uleverette/myfolder/reviews.csv': No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)\nrm $SCRATCH/myfolder/reviews.csv # delecte reviews.csv from $SCRATCH/myfolder/ directory\n')
#
# File /usr/local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd $SCRATCH/myfolder/ # cd = change directory to $SCRATCH/myfolder diredtory
# ls # list contents in directory ( List information about the FILEs (the current directory by default))
# pwd #  Print the full filename of the current working directory.
# Out:
# icecream
# /anvil/scratch/x-uleverette/myfolder

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# rm -r $SCRATCH/myfolder/icecream # delete icecream from $SCRATCH/myfolder/ directory recursively
# Out:
# rm: cannot remove '/anvil/scratch/x-uleverette/myfolder/icecream': No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)\nrm -r $SCRATCH/myfolder/icecream # delete icecream from $SCRATCH/myfolder/ directory recursively\n')
#
# File /usr/local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd $SCRATCH/myfolder/ # cd = change directory to $SCRATCH/myfolder diredtory
# ls # list contents in directory ( List information about the FILEs (the current directory by default))
# pwd #  Print the full filename of the current working directory.
# Out:
# /anvil/scratch/x-uleverette/myfolder

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 5
#
#
# - Create a new directory called mydinner in your home directory
#
# - Inside the mydinner directory, create the following files using the touch command:
#
# -        spaghetti.txt
#
# -        bread.txt
#
# -        broccoli.txt
#
# -        smoothie.txt
#
# -        tiramisu.txt
#
#  -       Optional: Feel free to create additional files for other dinner items you enjoy
#
# -    Display the contents of the mydinner directory using ls
#
# -    Edit each of the files to include the following ingredients:
#
# -        spaghetti.txt: noodle, tomato sauce
#
# -        bread.txt: bread, garlic, butter, cheese
#
# -        broccoli.txt: broccoli, salt, pepper
#
# -        smoothie.txt: strawberry, banana, milk
#
# -        tiramisu.txt: top-secret tiramisu recipe from granny
#
# -        Optional: Add ingredients to any additional files you created
#
#  -   Use the cat command to print the contents of each file
#
# -    Move the mydinner directory to SCRATCH and rename it to mybreakfast
#
# -    Display the contents of the SCRATCH directory
#
# -    Delete the mybreakfast directory

# %%
# !echo $HOME # view home directory
# Out:
# /home/x-uleverette

# %%
# %%bash
# ls -la # ls = show contents in the directory -la = size of files with dates
# Out:
# total 87037
# drwx------ 12 x-uleverette nogroup      159 Sep  9 22:29 .
# drwxr-xr-x  1 x-uleverette x-xsede       60 Sep  9 22:30 ..
# drwx------  2 x-uleverette nogroup        2 Jan 22  2025 .apptainer
# -rw-------  1 x-uleverette nogroup     1246 Sep  9 15:24 .bash_history
# -rw-r--r--  1 x-uleverette nogroup       18 Jan 17  2025 .bash_logout
# -rw-r--r--  1 x-uleverette nogroup      141 Jan 17  2025 .bash_profile
# -rw-r--r--  1 x-uleverette nogroup      810 Jan 17  2025 .bashrc
# drwxr-xr-x  7 x-uleverette nogroup        7 Apr 29 10:36 .cache
# drwxr-xr-x  5 x-uleverette nogroup        5 Apr 29 10:36 .config
# -rw-r--r--  1 x-uleverette nogroup      649 Jan 17  2025 .cshrc
# -rw-r--r--  1 x-uleverette nogroup      334 Jan 17  2025 .emacs
# -rw-r--r--  1 x-uleverette nogroup       61 Jan 17  2025 .inputrc
# drwxr-xr-x  2 x-uleverette nogroup      125 Sep  9 17:04 .ipynb_checkpoints
# drwxr-xr-x  3 x-uleverette nogroup        3 Aug 27 14:51 .ipython
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# mkdir $HOME/mydinner # mkdir = make directory create a directory inside of $HOME directory called mydinner

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd $HOME/mydinner # cd = change directory to $HOME/mydinner diredtory
# ls # list contents in directory ( List information about the FILEs (the current directory by default))
# pwd #  Print the full filename of the current working directory
# Out:
# /home/x-uleverette/mydinner

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd $HOME/mydinner/ # cd = change directory to $HOME/mydinner diredtory
# touch spaghetti.txt taco.txt salad.txt bread.txt smoothie.txt broccoli.txt tiramisu.txt pavbhaji.txt dalmahkani.txt pancit.txt empanadas.txt pho.txt tamales.txt collardgreens.txt cornbreaddressing.txt greenthaicurry.txt jerkedvegetables.txt callaloo.txt pilau.txt
# # touch = create a series of empty files in $HOME/mydinner directory named ???.txt
# ls # list contents in directory ( List information about the FILEs (the current directory by default))
# pwd # Print the full filename of the current working directory
# Out:
# bread.txt
# broccoli.txt
# callaloo.txt
# collardgreens.txt
# cornbreaddressing.txt
# dalmahkani.txt
# empanadas.txt
# greenthaicurry.txt
# jerkedvegetables.txt
# pancit.txt
# pavbhaji.txt
# pho.txt
# pilau.txt
# salad.txt
# smoothie.txt
# spaghetti.txt
# taco.txt
# tamales.txt
# tiramisu.txt
# /home/x-uleverette/mydinner

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# echo "noodle, tomato sauce" > $HOME/mydinner/spaghetti.txt # display a line of text and save to .txt %%file

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head $HOME/mydinner/spaghetti.txt  # view first 10 rows of data in the .txt file.
# Out:
# noodle, tomato sauce

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# echo "bread, garlic, butter, cheese" > $HOME/mydinner/bread.txt  # display a line of text and save to .txt file

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head $HOME/mydinner/bread.txt  # view first 10 rows of data in the .txt file.
# Out:
# bread, garlic, butter, cheese

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# echo "broccoli, salt, pepper" > $HOME/mydinner/broccoli.txt # display a line of text and save to .txt

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head $HOME/mydinner/broccoli.txt  # view first 10 rows of data in the .txt file.
# Out:
# broccoli, salt, pepper

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# echo "strawberry, banana, milk" > $HOME/mydinner/smoothie.txt # display a line of text and save to .txt filw

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head $HOME/mydinner/smoothie.txt  # view first 10 rows of data in the .txt file.
# Out:
# strawberry, banana, milk

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# echo "top secrete reciepe for tiramisu from granny" > $HOME/mydinner/tiramisu.txt # display a line of text and save to .txt file

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# head $HOME/mydinner/tiramisu.txt  # view first 10 rows of data in the .txt file.
# Out:
# top secrete reciepe for tiramisu from granny

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# wc /home/x-uleverette/mydinner/spaghetti.txt  # view counts = -c byte counts, -m character counts, -l newline counts.
# Out:
#  1  3 21 /home/x-uleverette/mydinner/spaghetti.txt

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# wc /home/x-uleverette/mydinner/tiramisu.txt  # view counts = -c byte counts, -m character counts, -l newline counts.
# Out:
#  1  7 45 /home/x-uleverette/mydinner/tiramisu.txt

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cat /home/x-uleverette/mydinner/tiramisu.txt /home/x-uleverette/mydinner/spaghetti.txt /home/x-uleverette/mydinner/smoothie.txt /home/x-uleverette/mydinner/broccoli.txt /home/x-uleverette/mydinner/bread.txt
# # concatenate files and print on the standard output
# Out:
# top secrete reciepe for tiramisu from granny
# noodle, tomato sauce
# strawberry, banana, milk
# broccoli, salt, pepper
# bread, garlic, butter, cheese

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# cd $HOME # cd = change directory to $HOME/mydinner diredtory
# pwd  Print the full filename of the current working directory
# Out:
# /home/x-uleverette

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# mv mydinner $SCRATCH/mybreakfast # mv = move (rename) files from mydinner to SCRATCH directory and rename mybreakfast

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# ls -la $SCRATCH # ls = show contents in the directory -la = size of files with dates
# Out:
# total 1027
# drwx------     4 x-uleverette nogroup   4096 Sep  9 22:41 .
# drwxr-xr-x 13386 nobody       nogroup 524288 Sep  9 20:10 ..
# drwxr-xr-x     2 x-uleverette x-xsede   4096 Sep  9 22:32 mybreakfast
# drwxr-xr-x     2 x-uleverette x-xsede   4096 Sep  9 12:52 myfolder

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# ls -la $SCRATCH/mybreakfast # ls = show contents in the directory -la = size of files with dates
# Out:
# total 5
# drwxr-xr-x 2 x-uleverette x-xsede 4096 Sep  9 22:32 .
# drwx------ 4 x-uleverette nogroup 4096 Sep  9 22:41 ..
# -rw-r--r-- 1 x-uleverette x-xsede   30 Sep  9 22:40 bread.txt
# -rw-r--r-- 1 x-uleverette x-xsede   23 Sep  9 22:40 broccoli.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 callaloo.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 collardgreens.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 cornbreaddressing.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 dalmahkani.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 empanadas.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 greenthaicurry.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 jerkedvegetables.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 pancit.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 pavbhaji.txt
# -rw-r--r-- 1 x-uleverette x-xsede    0 Sep  9 22:32 pho.txt
# ...

# %%
# %%bash
# # cell magic tells the kernal to expect a different language than the default Python.(TA Michael Hansen comments cannot be on the cell magic line)
# rm -rf $SCRATCH/mybreakfast # remove recursory force mybreakfast directory from $SCRATCH directory

# %%
# %%bash
# ls -la $SCRATCH # ls = show contents in the directory -la = size of files with dates
# Out:
# total 1026
# drwx------     3 x-uleverette nogroup   4096 Sep  9 22:41 .
# drwxr-xr-x 13386 nobody       nogroup 524288 Sep  9 20:10 ..
# drwxr-xr-x     2 x-uleverette x-xsede   4096 Sep  9 12:52 myfolder

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
