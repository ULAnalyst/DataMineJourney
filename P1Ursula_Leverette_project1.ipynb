# %% [markdown]
# # Project 10 -- Ursula Leverette

# %% [markdown]
# **TA Help:**
#
# - I followed the instructions outlined
# -   Projects
#     Spring 2025
#     TDM 10200
#     Project 10
# - https://the-examples-book.com/projects/spring2025/10200/project10
#
# **Collaboration:**

# %% [markdown]
# ## Question 1

# %%
# Step 1 - Import Required Library -The pandas library is imported(the pd is an alias for pandas - similar to database in sql) - click run
import pandas as pd

# %%
Step 2 - # Read CSV File Data to be loaded into pandas Data Frame (similar to tables in sql) - click run
myData = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")

# %%
Step 3 - # Display first 5 rows of data from the airports data frame(similar to Top 5 in sql) - click run
myData.head()
# Out:
#   iata               airport              city state country        lat  \
# 0  00M              Thigpen        Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#          long
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %% [markdown]
# Step 1 - Import Required Library -The pandas library is imported(the pd is an alias for pandas) -Click run
# Step 2 - Read CSV File Data - Click run
# Step 3 - Display first 5 rows of data from the airports data frame - Click run

# %% [markdown]
#  ![image.png](attachment:ce7193ad-f214-4c24-a3c6-92ca6a3b463c.png)

# %% [markdown]
# ## Question 2

# %%
# Checkiing the the shape/size of the dataset - see how many rows and columns are in the data frame with the airports data.(this is similar to Count * in sql)
myData.shape
# Taking a look at the last few(5) rows of data in the dataset(There is no direct function - in sql you can order by desc in sql)
myData.tail
# Filtering rows of data displayed based on conditions i.e.Display the airports by location 'City' and 'State'(similar to the where clause in sql)
myData[(myData['city'] == 'New York') & (myData['state'] == 'NY')]
# Filtering rows of data displayed based on conditions i.e. Display the airports by location 'City' and 'State'(similar to the where clause in sql)
myData[(myData['city'] == 'Indianapolis') & (myData['state'] == 'IN')]
# Filtering rows of data displayed based on conditions i.e. Display the airports by location 'City' and 'State'(similar to the where clause in sql)
myData[(myData['city'] == 'Houston') & (myData['state'] == 'TX')]

# %% [markdown]
# ![image.png](attachment:c34cdb24-d537-45f0-a829-9dc643adcfdf.png)
# ![image.png](attachment:9eb06864-b4c1-4803-ae8c-1c4cce468d9e.png)
# ![image.png](attachment:5ab7a41f-732d-4c96-96d2-382fd88489f2.png)

# %% [markdown]
# ## Question 3

# %%
# Counting Unique Values in a Column i.e. Display the number airport location 'State'(similar to the where clause in sql)
myData['state'].value_counts()

# %% [markdown]
# ![image.png](attachment:079d2847-0e1f-4166-9544-b4bbd141b757.png)

# %% [markdown]
# ## Question 4

# %%
# Step 1 - Import Required Library -The pandas library is imported(the pd is an alias for pandas - similar to database in sql) - click run
import pandas as pd
# Step 2 - Read CSV File Data to be loaded into pandas Data Frame (similar to tables in sql) - click run
myIData = pd.read_csv("/anvil/projects/tdm/data/icecream/combined/products.csv")
# Step 3 - Display first 5 rows of data from the icecream data frame(similar to Top 5 in sql) - click run
myIData.head()
# count the number of unique brands in the icecream dataset(this is similar to count distinct in sql)
Number_of_Unique_Brands = myIData["brand"].nunique()
# Print/Display the number of unique brands in the icecream dataset
print(Number_of_Unique_Brands)
# Counting Unique Values in a Column i.e. Display how many rows of data for each brands (similar to count in sql)
Count_of_Brand_Rows = myIData['brand'].value_counts()
# Print/Display the number of unique brands in the icecream dataset
print(Count_of_Brand_Rows)
# Importing Matplotlib for Visualization
import matplotlib.pyplot as plt
# Creating a Bar Chart - Testing
plt.bar(Count_of_Brand_Rows.index, Count_of_Brand_Rows)

# %% [markdown]
# ![image.png](attachment:7de12427-94d9-4547-9d18-6b9991902f85.png)
# ![image.png](attachment:d23c7818-2400-4276-ba67-28e7af3f0283.png)

# %% [markdown]
# ## Question 5

# %%
# Step 1 - Import Required Library -The pandas library is imported(the pd is an alias for pandas - similar to database in sql) - click run
import pandas as pd
# Step 2 - Read CSV File Data to be loaded into pandas Data Frame (similar to tables in sql) - click run
myRIData = pd.read_csv("/anvil/projects/tdm/data/icecream/combined/reviews.csv")
# Step 3 - Display first 5 rows of data from the icecream data frame(similar to Top 5 in sql) - click run
myRIData.head()
# count the number of unique brands in the icecream review dataset(this is similar to count distinct in sql)
CTN_Row_IRData = myRIData["brand"].nunique()
# Print/Display the number of unique brands in the icecream review dataset
print(CTN_Row_IRData)
# Importing Matplotlib for Visualization
import matplotlib.pyplot as plt
# Creating a Bar Chart - Testing
plt.bar(Count_of_Brand_Rows.index, Count_of_Brand_Rows)

# %% [markdown]
# ![image.png](attachment:b7ac5067-a267-4edc-9d5e-4565c7a52cb7.png)
# ![image.png](attachment:30be8e9b-df0a-4ded-8cfb-7d8e57239d2e.png)

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
