# %%
# Step 1 - Import Required Library -The pandas library is imported(the pd is an alias for pandas - similar to database in sql) - click run

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# Step 2 - # read_csv File Data to be loaded into pandas Data Frame (similar to tables in sql) - click run

# %%
myElection_Donations = pd.read_csv("/anvil/projects/tdm/data/election/itcont1980.txt", header=None, sep='|') #header=None: Indicates that the file does not contain column headers. Without this, Pandas will assume the first row contains column names.
#sep='|': Specifies that the columns in the file are separated by a pipe (|) character.

# %%
# Step 3 - Assign Column Names

# %%
myElection_Donations.columns = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]
#myElection_Donations.columns: Replaces the default column names (e.g., integers) with meaningful names based on the dataset's structure

# %%
# Step 4 - # Display first 5 rows of data from the election donations data frame(similar to Top 5 in sql) - click run

# %%
myElection_Donations.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 0  C00078279         A    M11               P  80031492155            22Y
# 1  C00078279         A    M11             NaN  79031415137             15
# 2  C00078279         A    M11             NaN  79031415137             15
# 3  C00078279         A    M11             NaN  79031415137             15
# 4  C00078287         A     Q1             NaN  79031231889             15
#
#    ENTITY_TP               NAME     CITY STATE  ...         EMPLOYER  \
# 0        NaN      MCKENNON, K R  MIDLAND    MI  ...              NaN
# 1        NaN        OREFFICE, P  MIDLAND    MI  ...  DOW CHEMICAL CO
# 2        NaN          DOWNEY, J  MIDLAND    MI  ...  DOW CHEMICAL CO
# 3        NaN           BLAIR, E  MIDLAND    MI  ...  DOW CHEMICAL CO
# 4        NaN  BLANCHARD, JOHN A  CHICAGO    IL  ...              NaN
#
#   OCCUPATION  TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  \
# 0        NaN      10031979.0              400       NaN     NaN       NaN
# 1        NaN      10261979.0             1500       NaN     NaN       NaN
# 2        NaN      10261979.0              300       NaN     NaN       NaN
# 3        NaN      10261979.0             1000       NaN     NaN       NaN
# 4        NaN       3201979.0              200       NaN     NaN       NaN
#
#    MEMO_CD                       MEMO_TEXT               SUB_ID
# 0      NaN  CONTRIBUTION REF TO INDIVIDUAL  3062020110011466469
# 1      NaN                             NaN  3061920110000382948
# 2      NaN                             NaN  3061920110000382949
# 3      NaN                             NaN  3061920110000382950
# 4      NaN                             NaN  3061920110000383914
#
# [5 rows x 21 columns]

# %%
#Counting the value that appears in the "STATE" column the most times

# %%
myElection_Donations['STATE'].value_counts(dropna = False)
# Out:
# STATE
# CA    37069
# TX    34862
# NY    25669
# IL    15895
# FL    15576
#       ...
# 01        3
# AS        2
# TU        1
# BE        1
# EL        1
# Name: count, Length: 62, dtype: int64

# %%
#Counting the value that appears in the "NAME" column the most times

# %%
myElection_Donations['NAME'].value_counts(dropna = False)
# Out:
# NAME
# AMERICAN MEDICAL POLITICAL ACTION COMMITTEE    769
# AMERICAN DENTAL POLITICAL ACTION COMMITTEE      96
# REPP, WARD W                                    89
# DEMOCRATIC CONGRESSIONAL DINNER COMMITTEE       65
# WILLIAMS, J D                                   64
#                                               ...
# MOYER, MONROE M                                  1
# NARVID, MICHAEL J                                1
# NORMAN, A E                                      1
# ASTON, ARTHUR                                    1
# STUART, HAROLD MRS                               1
# Name: count, Length: 217646, dtype: int64

# %%
#Display the myElection_Donations dataframe

# %%
myElection_Donations
# Out:
#           CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM  \
# 0       C00078279         A    M11               P  80031492155
# 1       C00078279         A    M11             NaN  79031415137
# 2       C00078279         A    M11             NaN  79031415137
# 3       C00078279         A    M11             NaN  79031415137
# 4       C00078287         A     Q1             NaN  79031231889
# ...           ...       ...    ...             ...          ...
# 308691  C99003063         N     YE             NaN  81031902915
# 308692  C99003063         N     YE             NaN  81031902915
# 308693  C00144170         N     YE             NaN  83032835154
# 308694  C00144170         N     YE             NaN  83032835154
# 308695  C00109637         N     YE             NaN  81020013947
#
#        TRANSACTION_TP  ENTITY_TP                NAME             CITY STATE  \
# 0                 22Y        NaN       MCKENNON, K R          MIDLAND    MI
# 1                  15        NaN         OREFFICE, P          MIDLAND    MI
# 2                  15        NaN           DOWNEY, J          MIDLAND    MI
# 3                  15        NaN            BLAIR, E          MIDLAND    MI
# 4                  15        NaN   BLANCHARD, JOHN A          CHICAGO    IL
# ...               ...        ...                 ...              ...   ...
# 308691             15        NaN    PLEMAN, THOMAS J  WESTLAKE ISLAND    CA
# 308692             15        NaN  SHEINBAUM, STANLEY      LOS ANGELES    CA
# 308693             15        NaN   PHILLIPS, LEONARD       SHREVEPORT    LA
# 308694             15        NaN   PHILLIPS, BETTY S       SHREVEPORT    LA
# 308695             15        NaN  STUART, HAROLD MRS            TULSA    OK
#
#         ...                 EMPLOYER OCCUPATION  TRANSACTION_DT  \
# 0       ...                      NaN        NaN      10031979.0
# 1       ...          DOW CHEMICAL CO        NaN      10261979.0
# 2       ...          DOW CHEMICAL CO        NaN      10261979.0
# 3       ...          DOW CHEMICAL CO        NaN      10261979.0
# 4       ...                      NaN        NaN       3201979.0
# ...     ...                      ...        ...             ...
# 308691  ...                  STUDENT        NaN      10171980.0
# 308692  ...                ECONOMIST        NaN      10161980.0
# 308693  ...  SKLAR & PHILLIPS OIL CO        NaN      10091981.0
# 308694  ...                HOUSEWIFE        NaN      10091981.0
# 308695  ...                HOUSEWIFE        NaN      12091980.0
#
#         TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  MEMO_CD  \
# 0                   400       NaN     NaN       NaN      NaN
# 1                  1500       NaN     NaN       NaN      NaN
# 2                   300       NaN     NaN       NaN      NaN
# 3                  1000       NaN     NaN       NaN      NaN
# 4                   200       NaN     NaN       NaN      NaN
# ...                 ...       ...     ...       ...      ...
# 308691              500       NaN     NaN       NaN      NaN
# 308692              500       NaN     NaN       NaN      NaN
# 308693              500       NaN     NaN       NaN      NaN
# 308694              500       NaN     NaN       NaN      NaN
# 308695              500       NaN     NaN       NaN      NaN
#
#                              MEMO_TEXT               SUB_ID
# 0       CONTRIBUTION REF TO INDIVIDUAL  3062020110011466469
# 1                                  NaN  3061920110000382948
# 2                                  NaN  3061920110000382949
# 3                                  NaN  3061920110000382950
# 4                                  NaN  3061920110000383914
# ...                                ...                  ...
# 308691                             NaN  3061920110000777082
# 308692                             NaN  3061920110000777083
# 308693                             NaN  3061920110000579479
# 308694                             NaN  3061920110000579480
# 308695                             NaN  3061920110000674036
#
# [308696 rows x 21 columns]
