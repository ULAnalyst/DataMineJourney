# %% [markdown]
# # Project 9 -- Ursula Leverette

# %% [markdown]
# **TA Help:**
#
#
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Overflow
#
# (describe any information that you learned from internet resources, including the URLs)
#
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).
#
# ## Question 1
#
#  - 1.1. Create a trigger called "update_yearID" that automatically updates the "yearID" column in the "Teams" table to the current year whenever a new row is inserted
#  - 1.2. Insert a new row into the "Teams" table with a yearID of 0
#  - 1.3. Query the "Teams" table to see if the yearID column has been updated.

# %%
import sqlite3 # import the sqlite library to connect and work with databases in Python

# %%
read_only_Lahman = sqlite3.connect('/anvil/projects/tdm/data/lahman/lahman.db') # load the lahman database from read-only location
local_lahman = sqlite3.connect('./lahman.db') # create a local copy of the lahman database on my system. 

read_only_Lahman.backup(local_lahman) # use the backup feature to compy all data from the read-only database to my local file. 
read_only_Lahman.close() # close both database connections to complete the operation. 
local_lahman.close()

# %% [markdown]
# %%sql sqlite:///./lahman.db
# Select *                     # select all columns from the table
# From Teams                   # query all rows from the Teams table
# Limit 5;                     # limit the output to the first 5 rows only

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From Teams
# Limit 5;
# Out:
# Done.
# [(1871, 'NA', 'BS1', 'BNA', '', 3, 31, '', 20, 10, '', '', 'N', '', 401, 1372, 426, 70, 37, 3, 60, 19, 73, 16, '', '', 303, 109, 3.55, 22, 1, 3, 828, 367, 2, 42, 23, 243, 24, 0.834, 'Boston Red Stockings', 'South End Grounds I', '', 103, 98, 'BOS', 'BS1', 'BS1'),
#  (1871, 'NA', 'CH1', 'CNA', '', 2, 28, '', 19, 9, '', '', 'N', '', 302, 1196, 323, 52, 21, 10, 60, 22, 69, 21, '', '', 241, 77, 2.76, 25, 0, 1, 753, 308, 6, 28, 22, 229, 16, 0.829, 'Chicago White Stockings', 'Union Base-Ball Grounds', '', 104, 102, 'CHI', 'CH1', 'CH1'),
#  (1871, 'NA', 'CL1', 'CFC', '', 8, 29, '', 10, 19, '', '', 'N', '', 249, 1186, 328, 35, 40, 7, 26, 25, 18, 8, '', '', 341, 116, 4.11, 23, 0, 0, 762, 346, 13, 53, 34, 234, 15, 0.818, 'Cleveland Forest Citys', 'National Association Grounds', '', 96, 100, 'CLE', 'CL1', 'CL1'),
# ...

# %% [markdown]
# CREATE TRIGGER IF NOT EXISTS update_yearID     # create a trigger named update_yearID if it doesn't already exist
# AFTER INSERT ON Teams                         # fire the trigger after a new row is inserted into the Teams table
# FOR EACH ROW                                  # execute the trigger for every row that is inserted
# BEGIN
#     UPDATE Teams                              # update the Teams table
#     SET yearID = strftime('%Y', 'now')        # set yearID to the current year as a string
#     WHERE teamID = NEW.teamID;                # only update the row for the inserted team's teamID
# END;                                          # end the trigger

# %%
# %%sql sqlite:///./lahman.db
# CREATE TRIGGER IF NOT EXISTS update_yearID
# AFTER INSERT ON Teams
# FOR EACH ROW
# BEGIN
#     UPDATE Teams
#     SET yearID = strftime('%Y', 'now')
#     WHERE teamID = NEW.teamID;
# END;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# INSERT INTO Teams (teamID, name, yearID)  # insert a new row into the Teams table specifying teamID, name, and yearID columns
# VALUES ('team1', 'Test Team', 0);          # insert values for a team with ID 'team1', name 'Test Team', and yearID 0 (to be updated by trigger)

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO Teams (teamID, name, yearID)
# VALUES ('team1', 'Test Team', 0);
# Out:
# 1 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# Select *                     # select all columns from the table
# From Teams                   # query all rows from the Teams table
# where name = 'Test Team'     # filter rows to those where the name column matches 'Test Team'
# Limit 5;                    # limit the output to the first 5 rows that meet the condition

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From Teams
# where name = 'Test Team'
# Limit 5;
# Out:
# Done.
# [(2025, None, 'team1', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'Test Team', None, None, None, None, None, None, None),
#  (2025, None, 'team1', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'Test Team', None, None, None, None, None, None, None)]

# %% [markdown]
# ## Question 2
#  - 2.1. Create a new table called "DeathRecords" with playerID, yearID, monthID, and dayID columns,
#  - 2.2. Create a trigger that automatically updates the deathYear, deathMonth, and deathDay columns in the "People" table whenever a new row is inserted into the "DeathRecords" table,
#  - 2.3. Insert a new row into the "DeathRecords" table and verify that the trigger works by checking the "People" table,
#  - 2.4. Insert multiple rows into the "DeathRecords" table and verify that the trigger works for all of the rows by checking the "People" table.

# %%
# %%sql sqlite:///./lahman.db
# DROP TABLE DeathRecords;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# CREATE TABLE DeathRecords (    # create a new table named DeathRecords
#     playerID TEXT PRIMARY KEY,  # playerID column of type TEXT, set as the primary key to uniquely identify each record
#     yearID INTEGER NOT NULL,    # yearID column of type INTEGER, cannot be NULL, stores the year of death
#     monthID INTEGER NOT NULL,   # monthID column of type INTEGER, cannot be NULL, stores the month of death
#     dayID INTEGER NOT NULL      # dayID column of type INTEGER, cannot be NULL, stores the day of death
#     );

# %%
# %%sql sqlite:///./lahman.db
# CREATE TABLE DeathRecords (
#     playerID TEXT PRIMARY KEY,
#     yearID INTERGER NOT NULL,
#     monthID INTERGER NOT NULL,
#     dayID INTERGER NOT NULL
#     );
# Out:
# Done.
# []

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO DeathRecords (playerID, yearID, monthID, dayID)
# VALUES ('abreubo02', 2025, 1, 1);
# Out:
# 1 rows affected.
# []

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From DeathRecords
# ;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# CREATE TRIGGER IF NOT EXISTS update_yr_mt_dy  # create a trigger named update_yr_mt_dy if it does not already exist
# AFTER INSERT ON DeathRecords                   # trigger will fire after a new row is inserted into DeathRecords table
# FOR EACH ROW                                   # execute the trigger once for each inserted row
# BEGIN
#     UPDATE People                              # update the People table
#     SET deathYear = NEW.yearID,                # set deathYear to the yearID from the newly inserted DeathRecords row
#         deathMonth = NEW.monthID,              # set deathMonth to the monthID from the newly inserted DeathRecords row
#         deathDay = NEW.dayID                    # set deathDay to the dayID from the newly inserted DeathRecords row
#     WHERE playerID = NEW.playerID;             # update the row in People matching the playerID of the new DeathRecords row
# END;

# %%
# %%sql sqlite:///./lahman.db
# CREATE TRIGGER IF NOT EXISTS update_yr_mt_dy
# AFTER INSERT ON DeathRecords
# FOR EACH ROW
# BEGIN
#     Update People
#     set deathYear = NEW.yearID,
#     deathMonth = NEW.monthID,
#     deathDay = NEW.dayID
#     Where playerID = NEW.playerID;
#
#
# END;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# INSERT INTO DeathRecords (playerID, yearID, monthID, dayID)  # insert a new row into DeathRecords with death details
# VALUES ('abreubo01', 2025, 1, 1);                          # values specify player's ID, year, month, and day of death

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO DeathRecords (playerID, yearID, monthID, dayID)
# VALUES ('abreubo01', 2025, 1, 1);
# Out:
# 1 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# Select *                     # select all columns from the table
# From DeathRecords            # query all rows from the DeathRecords table
# LIMIT 5;                    # limit the output to the first 5 rows only

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From DeathRecords
#
# ;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# Select *                    # select all columns from the table
# From People                # query all rows from the People table
# LIMIT 50;                  # limit output to the first 50 rows only

# %%
# %%sql sqlite:///./lahman.db
# Select
# *
# From People
# where playerID = 'abreubo01'
# LIMIT 50
# ;
# Out:
# Done.
# [('abreubo01', 1974, 3, 11, 'Maracay', 'Venezuela', 'Aragua', '', '', '', '', '', '', 'Bobby', 'Abreu', 'Bob Kelly', 220, 72, 'L', 'R', '1996-09-01', 'abreubo01', '2014-09-28', 'abreb001')]

# %%
# %%sql sqlite:///./lahman.db
#
#
# CREATE TRIGGER IF NOT EXISTS update_yr_mt_dy
# AFTER INSERT ON DeathRecords
# FOR EACH ROW
# BEGIN
#     UPDATE People
#     SET deathYear = NEW.yearID,
#         deathMonth = NEW.monthID,
#         deathDay = NEW.dayID
#     WHERE playerID = NEW.playerID;
# END;
#
#
# INSERT INTO DeathRecords (playerID, yearID, monthID, dayID)
# VALUES ('abreubo01', 2025, 1, 1);
# Out:
# Done.
# 1 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# INSERT INTO DeathRecords (playerID, yearID, monthID, dayID)  # insert multiple rows into the DeathRecords table with details about player deaths
# VALUES                                                      # values to be inserted in each row follow
# ('pintore01', 2025, 2, 1),                                 # second player death record (playerID, year, month, day)
# ('hundlni01', 2025, 3, 1),                                 # third player death record
# ('detwiro01', 2025, 4, 1);                                 # fourth player death record

# %%
# %%sql sqlite:///./lahman.db
# INSERT INTO DeathRecords (playerID, yearID, monthID, dayID)
# VALUES
# ('pintore01', 2025, 2, 1),
# ('hundlni01', 2025, 3, 1),
# ('detwiro01', 2025, 4, 1);
# Out:
# 3 rows affected.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# Select *                    # select all columns from the table
# From DeathRecords           # query all rows from the DeathRecords table
# LIMIT 5;                   # limit the output to the first 5 rows only

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From DeathRecords
# LIMIT 5
# ;
# Out:
# Done.
# [('bandyje01', 2025, 5, 1),
#  ('meyeral01', 2025, 6, 1),
#  ('perdoan01', 2025, 7, 1),
#  ('johndoe01', 2025, 10, 1),
#  ('janedoe01', 2025, 11, 1)]

# %% [markdown]
# %%sql sqlite:///./lahman.db
# Select *                    # select all columns from the table
# From People                # query all rows from the People table
# LIMIT 50;                  # limit the output to the first 50 rows only

# %%
# %%sql sqlite:///./lahman.db
# Select
# *
# From People
#
# LIMIT 50
# ;
# Out:
# Done.
# [('aardsda01', 1981, 12, 27, 'Denver', 'USA', 'CO', '', '', '', '', '', '', 'David', 'Aardsma', 'David Allan', 215, 75, 'R', 'R', '2004-04-06', 'aardsda01', '2015-08-23', 'aardd001'),
#  ('aaronha01', 1934, 2, 5, 'Mobile', 'USA', 'AL', 2021, 1, 22, 'USA', 'GA', 'Atlanta', 'Hank', 'Aaron', 'Henry Louis', 180, 72, 'R', 'R', '1954-04-13', 'aaronha01', '1976-10-03', 'aaroh101'),
#  ('aaronto01', 1939, 8, 5, 'Mobile', 'USA', 'AL', 1984, 8, 16, 'USA', 'GA', 'Atlanta', 'Tommie', 'Aaron', 'Tommie Lee', 190, 75, 'R', 'R', '1962-04-10', 'aaronto01', '1971-09-26', 'aarot101'),
#  ('aasedo01', 1954, 9, 8, 'Orange', 'USA', 'CA', '', '', '', '', '', '', 'Don', 'Aase', 'Donald William', 190, 75, 'R', 'R', '1977-07-26', 'aasedo01', '1990-10-03', 'aased001'),
#  ('abadan01', 1972, 8, 25, 'Palm Beach', 'USA', 'FL', '', '', '', '', '', '', 'Andy', 'Abad', 'Fausto Andres', 184, 73, 'L', 'L', '2001-09-10', 'abadan01', '2006-04-13', 'abada001'),
# ...

# %% [markdown]
# ## Question 3
#
#  - 3.1. Create a view called "TallPlayers" that returns the playerID, nameFirst, nameLast, height, and weight columns from the "People" table, but only for players who are taller than 6 feet (72 inches),
#  - 3.2. Query the "TallPlayers" view to see if it returns the expected results,
#  - 3.3. Create a view called "TallHeavyPlayers" that returns the playerID, nameFirst, nameLast, height, and weight columns from the "People" table, but only for players who are taller than 6 feet (72 inches), have a non-NULL weight, and were born in 1994, ordered by weight in descending order,
#  - 3.4. Query the "TallHeavyPlayers" view to get the top 5 heaviest players who were born in 1994 and are over 6 feet tall,
#  - 3.5. Query the "TallHeavyPlayers" view again to get the top 7 heaviest players who were born in 1994 and are over 6 feet tall.

# %% [markdown]
# %%sql sqlite:///./lahman.db
# CREATE VIEW IF NOT EXISTS vw_Dimension_TallPlayers AS   # create a view named vw_Dimension_TallPlayers if it doesn't already exist
# SELECT playerID,                                      # select playerID column
#        nameFirst,                                     # select first name
#        nameLast,                                      # select last name
#        height,                                        # select height
#        weight                                         # select weight
# FROM People                                               # from the People table
# WHERE height >= 72;                                     # only include players who are 72 inches or taller

# %%
# %%sql sqlite:///./lahman.db
# CREATE VIEW IF NOT EXISTS vw_Dimension_TallPlayers AS
# SELECT
# playerID,
# nameFirst,
# nameLast,
# height,
# weight
# FROM People
# WHERE height >=72;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# SELECT *                    # select all columns from the table
# FROM vw_Dimension_TallPlayers # query all rows from the vw_Dimension_TallPlayers view
# LIMIT 5;                   # limit the output to the first 5 rows only

# %%
# %%sql sqlite:///./lahman.db
# SELECT *
# FROM vw_Dimension_TallPlayers
# LIMIT 5;
# Out:
# Done.
# [('aardsda01', 'David', 'Aardsma', 75, 215),
#  ('aaronha01', 'Hank', 'Aaron', 72, 180),
#  ('aaronto01', 'Tommie', 'Aaron', 75, 190),
#  ('aasedo01', 'Don', 'Aase', 75, 190),
#  ('abadan01', 'Andy', 'Abad', 73, 184)]

# %%
# %%sql sqlite:///./lahman.db
# select *
# from people
# LIMIT 2;
# Out:
# Done.
# [('aardsda01', 1981, 12, 27, 'Denver', 'USA', 'CO', '', '', '', '', '', '', 'David', 'Aardsma', 'David Allan', 215, 75, 'R', 'R', '2004-04-06', 'aardsda01', '2015-08-23', 'aardd001'),
#  ('aaronha01', 1934, 2, 5, 'Mobile', 'USA', 'AL', 2021, 1, 22, 'USA', 'GA', 'Atlanta', 'Hank', 'Aaron', 'Henry Louis', 180, 72, 'R', 'R', '1954-04-13', 'aaronha01', '1976-10-03', 'aaroh101')]

# %% [markdown]
# %%sql sqlite:///./lahman.db
# CREATE VIEW IF NOT EXISTS vw_Dimension_TallHeavyPlayers AS  # create the view named vw_Dimension_TallHeavyPlayers if it does not already exist
# SELECT
#     playerID,          # select playerID column
#     birthYear,         # select birthYear column
#     nameFirst,         # select player's first name
#     nameLast,          # select player's last name
#     height,            # select height column
#     weight             # select weight column
# FROM People            # from the People table
# WHERE
#     height >= 72       # filter for players who are at least 72 inches tall
#     AND weight IS NOT NULL  # exclude players with unknown weight
#     AND birthYear = 1994    # include only players born in 1994
# ;

# %%
# %%sql sqlite:///./lahman.db
# CREATE VIEW IF NOT EXISTS vw_Dimension_TallHeavyPlayers AS
# SELECT
# playerID,
# birthYear,
# nameFirst,
# nameLast,
# height,
# weight
# FROM People
# WHERE height >=72
# and weight is not NULL
# and birthYear = 1994
# ;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# SELECT *                          # select all columns from the table
# FROM vw_Dimension_TallHeavyPlayers  # query all rows from the vw_Dimension_TallHeavyPlayers view
# ORDER BY weight DESC              # sort the results by weight in descending order (heaviest players first)
# LIMIT 5;                         # limit the output to the first 5 rows only

# %%
# %%sql sqlite:///./lahman.db
# SELECT *
# FROM vw_Dimension_TallHeavyPlayers
# ORDER BY weight DESC
# LIMIT 5;
# Out:
# Done.
# [('castidi01', 1994, 'Diego', 'Castillo', 75, 268),
#  ('perdoan01', 1994, 'Angel', 'Perdomo', 80, 265),
#  ('ponceco01', 1994, 'Cody', 'Ponce', 78, 255),
#  ('quezajo01', 1994, 'Johan', 'Quezada', 81, 255),
#  ('wellsty01', 1994, 'Tyler', 'Wells', 80, 255)]

# %% [markdown]
# %%sql sqlite:///./lahman.db
# SELECT *                      # select all columns from the table or view
# FROM vw_Dimension_TallHeavyPlayers  # query all rows from the vw_Dimension_TallHeavyPlayers view
# ORDER BY weight DESC          # sort the results by the weight column in descending order (heaviest first)
# LIMIT 7;                     # limit the output to the first 7 rows only

# %%
# %%sql sqlite:///./lahman.db
# SELECT *
# FROM vw_Dimension_TallHeavyPlayers
# ORDER BY weight DESC
# LIMIT 7;
# Out:
# Done.
# [('castidi01', 1994, 'Diego', 'Castillo', 75, 268),
#  ('perdoan01', 1994, 'Angel', 'Perdomo', 80, 265),
#  ('ponceco01', 1994, 'Cody', 'Ponce', 78, 255),
#  ('quezajo01', 1994, 'Johan', 'Quezada', 81, 255),
#  ('wellsty01', 1994, 'Tyler', 'Wells', 80, 255),
#  ('alonspe01', 1994, 'Pete', 'Alonso', 74, 253),
#  ('bednada01', 1994, 'David', 'Bednar', 73, 250)]

# %% [markdown]
# ## Question 4
#
#  - 4.1. Start a transaction that has 3 INSERT statements, inserting 3 new rows into the "DeathRecords" table,
#  - 4.2. Run the transaction and verify that all 3 rows were inserted into the "DeathRecords",
#  - 4.3. Start a transaction that has 2 INSERT statements, inserting 2 new rows into the "DeathRecords" table, but make sure that one of the INSERT statements fails,
#  - 4.4. Rollback the transaction and verify that no rows were inserted into the "DeathRecords" table.

# %% [markdown]
# %config SqlMagic.autocommit = False # Configure SqlMagic to disable autocommit mode

# %%
# %config SqlMagic.autocommit = False

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Create a savepoint called insert_DeathRecords to group the following insert operations into a single transaction scope
# SAVEPOINT insert_DeathRecords;
#
# # Insert new death record for players
# INSERT INTO DeathRecords VALUES ('bandyje01', 2025, 5, 1);
# INSERT INTO DeathRecords VALUES ('meyeral01', 2025, 6, 1);
# INSERT INTO DeathRecords VALUES ('perdoan01', 2025, 7, 1);
#
# # Release the savepoint, which releases the changes made since the savepoint was created
# RELEASE insert_DeathRecords;
#
# # Commit the transaction to save all changes permanently to the database
# COMMIT;

# %%
# %%sql sqlite:///./lahman.db
# SAVEPOINT insert_DeathRecords;
#
# INSERT INTO DeathRecords VALUES ('bandyje01', 2025, 5, 1);
# INSERT INTO DeathRecords VALUES ('meyeral01', 2025, 6, 1);
# INSERT INTO DeathRecords VALUES ('perdoan01', 2025, 7, 1);
#
# RELEASE insert_DeathRecords;
# COMMIT;
# Out:
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# (sqlite3.OperationalError) cannot commit - no transaction is active
# [SQL: COMMIT;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Select all columns and rows from the DeathRecords table to see all death records stored
# SELECT * FROM DeathRecords;

# %%
# %%sql sqlite:///./lahman.db
# SELECT * FROM DeathRecords;
# Out:
# Done.
# [('bandyje01', 2025, 5, 1),
#  ('meyeral01', 2025, 6, 1),
#  ('perdoan01', 2025, 7, 1)]

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Create a savepoint named 'insert_DeathRecords' to mark a point for nested transactions
# SAVEPOINT insert_DeathRecords;
#
# # Insert a death record for player with ID
# INSERT INTO DeathRecords VALUES ('castidi01', 2025, 8, 1);
# INSERT INTO DeathRecords VALUES ('quezajo01', 2025, 9, NULL);
#
# # Release the savepoint, committing all changes made since the savepoint was set
# RELEASE insert_DeathRecords;
#
# # Commit the transaction to persist all changes to the database
# COMMIT;

# %%
# %%sql sqlite:///./lahman.db
# SAVEPOINT insert_DeathRecords;
#
#   INSERT INTO DeathRecords VALUES ('castidi01', 2025, 8, 1);
#
#   INSERT INTO DeathRecords VALUES ('quezajo01', 2025, 9, NULL);
# RELEASE insert_DeathRecords;
# COMMIT;
# Out:
# Done.
# 1 rows affected.
# (sqlite3.IntegrityError) NOT NULL constraint failed: DeathRecords.dayID
# [SQL: INSERT INTO DeathRecords VALUES ('quezajo01', 2025, 9, NULL);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Select all columns for players in DeathRecords table with playerIDs 'castidi01' or 'quezajo01'
# SELECT *
# FROM DeathRecords
# WHERE playerID in ('castidi01', 'quezajo01');

# %%
# %%sql sqlite:///./lahman.db
# SELECT *
# FROM DeathRecords
# WHERE playerID in ('castidi01', 'quezajo01');
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Begin a transaction block
# BEGIN;
#
# # Create a savepoint named DeathRecords_insert2 for nested transaction control
# SAVEPOINT DeathRecords_insert2;
#
# # Insert new record into DeathRecords if it does not conflict with an existing entry (ignore on conflict)
# INSERT OR IGNORE INTO DeathRecords VALUES ('castidi01', 2025, 8, 1);
#
# # Insert another new record into DeathRecords if it does not conflict (dayID is NULL here)
# INSERT OR IGNORE INTO DeathRecords VALUES ('quezajo01', 2025, 9, NULL);
#
# # Rollback to savepoint to undo changes done after this savepoint was created (ignores the above inserts effectively)
# ROLLBACK TO DeathRecords_insert2;
#
# # Commit the transaction, finalizing changes (in this case, nothing will be committed due to rollback)
# COMMIT;

# %%
# %%sql sqlite:///./lahman.db
# BEGIN;
# SAVEPOINT DeathRecords_insert2;
# INSERT OR IGNORE INTO DeathRecords VALUES ('castidi01', 2025, 8, 1);
# INSERT OR IGNORE INTO DeathRecords VALUES ('quezajo01', 2025, 9, NULL);
#
# ROLLBACK TO DeathRecords_insert2;
# COMMIT;
# Out:
# Done.
# Done.
# 1 rows affected.
# 0 rows affected.
# Done.
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Select all columns from the DeathRecords table where the playerID matches 'castidi01'
# SELECT *
# FROM DeathRecords
# WHERE playerID = 'castidi01';

# %%
# %%sql sqlite:///./lahman.db
# SELECT *
# FROM DeathRecords
# WHERE playerID = 'castidi01';
# Out:
# Done.
# []

# %% [markdown]
# Question 5
#  - 5.1. Create a trigger that automatically updates the "People" table whenever a new player is added to the "DeathRecords" table,
#  - 5.2. Create a view called "DeceasedPlayers" that returns the playerID, nameFirst, nameLast, deathYear, deathMonth, and deathDay columns from the "MyPlayers" table, but only for players who have a non-NULL value in the deathYear column,
#  - 5.3. Start a transaction that has 3 INSERT statements, inserting 3 new rows into the "DeathRecords" table,
#  - 5.4. Run the transaction and verify that all 3 rows were inserted into the "DeathRecords" table,
#  - 5.5. Query the "DeceasedPlayers" view to see if the new players were added to the view.

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Create a trigger named 'update_myplayers_death' that fires after a new row is inserted into the DeathRecords table
# CREATE TRIGGER IF NOT EXISTS update_myplayers_death
# AFTER INSERT ON DeathRecords
# FOR EACH ROW
# BEGIN
#     # Update the People table to set deathYear, deathMonth, and deathDay to the corresponding values in the newly inserted DeathRecords row
#     UPDATE People
#     SET deathYear = NEW.yearID,
#         deathMonth = NEW.monthID,
#         deathDay = NEW.dayID
#     WHERE playerID = NEW.playerID;
# END;

# %%
# %%sql sqlite:///./lahman.db
# CREATE TRIGGER IF NOT EXISTS update_myplayers_death
# AFTER INSERT ON DeathRecords
# FOR EACH ROW
# BEGIN
#     UPDATE People
#     SET deathYear = NEW.yearID,
#         deathMonth = NEW.monthID,
#         deathDay = NEW.dayID
#     WHERE playerID = NEW.playerID;
# END;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# Select *
# From MyPlayers # No MyPlayers table
# ;

# %%
# %%sql sqlite:///./lahman.db
# Select *
# From MyPlayers
# ;
# Out:
# (sqlite3.OperationalError) no such table: MyPlayers
# [SQL: Select *
# From MyPlayers
# ;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Create a view named vw_Dimension_DeceasedPlayers if it doesn't already exist
# CREATE VIEW IF NOT EXISTS vw_Dimension_DeceasedPlayers AS
# SELECT
#     playerID,    # select playerID column
#     nameFirst,   # select first name column
#     nameLast,    # select last name column
#     deathYear,   # select death year column
#     deathMonth,  # select death month column
#     deathDay     # select death day column
# FROM People     # from the People table
# WHERE deathYear IS NOT NULL;  # include only players who have a known year of death

# %%
# %%sql sqlite:///./lahman.db
# CREATE VIEW IF NOT EXISTS vw_Dimension_DeceasedPlayers AS
# SELECT
# playerID,
# nameFirst,
# nameLast,
# deathYear,
# deathMonth,
# deathDay
# FROM People
# WHERE deathYear IS NOT NULL;
# Out:
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Select all columns and rows from the view vw_Dimension_DeceasedPlayers
#
# Select
# *
# From vw_Dimension_DeceasedPlayers
# LIMIT 5;# Limit the output to the first 5 rows only for sample viewing

# %%
# %%sql sqlite:///./lahman.db
# Select
# *
# From vw_Dimension_DeceasedPlayers
# LIMIT 5;
# Out:
# Done.
# [('aardsda01', 'David', 'Aardsma', '', '', ''),
#  ('aaronha01', 'Hank', 'Aaron', 2021, 1, 22),
#  ('aaronto01', 'Tommie', 'Aaron', 1984, 8, 16),
#  ('aasedo01', 'Don', 'Aase', '', '', ''),
#  ('abadan01', 'Andy', 'Abad', '', '', '')]

# %%
# %%sql sqlite:///./lahman.db
# # Begin a new transaction to group the following insertion operations
# BEGIN;
#
# # Set a savepoint named DeathRecords_insert3 to allow nested transaction control
# SAVEPOINT DeathRecords_insert3;
#
# # Insert new record into DeathRecords if it does not conflict with an existing entry (ignore on conflict)
# INSERT OR IGNORE INTO DeathRecords VALUES('johndoe01', 2025, 10, 1);
# INSERT OR IGNORE INTO DeathRecords VALUES('janedoe01', 2025, 11, 1);
# INSERT OR IGNORE INTO DeathRecords VALUES('foobar01', 2025, 12, 1);
#
# # Release the savepoint, finalizing changes made after the savepoint was set
# RELEASE DeathRecords_insert3;
#
# # Commit the transaction to permanently save all changes to the database
# COMMIT;
# Out:
# Done.
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# Done.
# []

# %%
# %%sql sqlite:///./lahman.db
# BEGIN;
# SAVEPOINT DeathRecords_insert3;
#
#     INSERT OR IGNORE INTO DeathRecords VALUES('johndoe01', 2025, 10, 1);
#     INSERT OR IGNORE INTO DeathRecords VALUES('janedoe01', 2025, 11, 1);
#     INSERT OR IGNORE INTO DeathRecords VALUES('foobar01', 2025, 12, 1);
# RELEASE DeathRecords_insert3;
# COMMIT;
# Out:
# Done.
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# Done.
# []

# %% [markdown]
# %%sql sqlite:///./lahman.db
# # Select all columns from the DeathRecords table for players
# FROM DeathRecords
# WHERE playerID IN ('johndoe01', 'janedoe01', 'foobar01');

# %%
# %%sql sqlite:///./lahman.db
# SELECT *
# FROM DeathRecords
# WHERE playerID IN ('johndoe01', 'janedoe01', 'foobar01');
# Out:
# Done.
# [('foobar01', 2025, 12, 1),
#  ('janedoe01', 2025, 11, 1),
#  ('johndoe01', 2025, 10, 1)]

# %% [markdown]
# %%sql
# # Select all columns from the DeceasedPlayers table for players
# FROM DeceasedPlayers
# WHERE playerID IN ('johndoe01', 'janedoe01', 'foobar01');

# %%
# %%sql
# SELECT *
# FROM DeceasedPlayers
# WHERE playerID IN ('johndoe01', 'janedoe01', 'foobar01');
# Out:
#  * sqlite:///./lahman.db
# Done.
# []

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
